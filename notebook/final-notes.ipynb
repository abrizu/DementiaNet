# %%
will eventually include the notes from both biomarker and mri into one final experimentation.

includes:
- all trials and errors, methodologies
- lstm vs regular cnn for biomarker (no sequential data, no use for lstm)
- test accuracies and how to improve it, reduce overfitting


final adjustments:
- need a way to pull data from kaggle, and use the data online rather than apply the mri data locally
- get to work on finalizing the paper
