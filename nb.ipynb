# %% [markdown]
# Current Sources:

# %% [markdown]
# https://www.kaggle.com/docs/api#interacting-with-datasets # for interacting with kaggle api
# https://www.kaggle.com/datasets/ninadaithal/imagesoasis
# https://www.kaggle.com/code/joaovm3/alzheimer-s-detection-using-dl#Import-Dataset
