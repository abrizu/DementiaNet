# %% [markdown]
# Current Sources:

# %% [markdown]
# https://www.kaggle.com/docs/api#interacting-with-datasets # for interacting with kaggle api
# https://www.kaggle.com/datasets/ninadaithal/imagesoasis
# https://www.kaggle.com/code/joaovm3/alzheimer-s-detection-using-dl#Import-Dataset

# %% [markdown]
# (.venv) PS C:\Users\Aaron\Downloads\480mri> py mri.py
# Using device: cuda | Active: True | Version: 11.8 | Count: 1 | Name: NVIDIA GeForce GTX 1080
# Image counts per class: {'Mild Dementia': 5002, 'Moderate Dementia': 488, 'Non Demented': 67222, 'Very mild Dementia': 13725}
#
# Training model...
# Epoch [1/3] - Loss: 0.3260
# Epoch [2/3] - Loss: 0.0875
# Epoch [3/3] - Loss: 0.0302
#
# Training finished in 5.74 minutes
#
# Test Accuracy: 99.76%
#
# Classification Report:
#                      precision    recall  f1-score   support
#
#      Mild Dementia       1.00      1.00      1.00       961
#  Moderate Dementia       1.00      1.00      1.00        84
#       Non Demented       1.00      1.00      1.00     13458
# Very mild Dementia       0.99      0.99      0.99      2785
#
#           accuracy                           1.00     17288
#          macro avg       1.00      1.00      1.00     17288
#       weighted avg       1.00      1.00      1.00     17288
#
# (.venv) PS C:\Users\Aaron\Downloads\480mri>
#
# Note: Accuracy too high may be the result of overfitting data.
# Additionally, data is skewed due to 62k imgs in non-dementia, less in others

# %%
class MRI_CNN(nn.Module):
    def __init__(self, num_classes=4): # 4 classes: non-demented, very mild, mild, moderate
        super().__init__()
        self.norm = nn.BatchNorm2d(1)

        self.conv1 = nn.Conv2d(1, 16, kernel_size=3, padding=1)
        self.bn1   = nn.BatchNorm2d(16)
        self.pool  = nn.MaxPool2d(2,2)
        
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, padding=1)
        self.bn2   = nn.BatchNorm2d(32)
        
        self.conv3 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.bn3   = nn.BatchNorm2d(64)
        
        self.relu  = nn.ReLU()
        self.drop  = nn.Dropout(0.2)
        
        self.fc1   = nn.Linear(64 * 16 * 16, 128)
        self.fc2   = nn.Linear(128, num_classes)

# this is currently the model im using for above. aim to simplify the model to prevent overfitting / improve runtime
